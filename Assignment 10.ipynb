# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('adult.csv')
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                  ?    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %% [markdown]
# ## ***1.Display Top 10 Rows of The Dataset***

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2  Married-civ-spouse    Protective-serv        Husband  White    Male
# 3  Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4       Never-married                  ?      Own-child  White  Female
# 5       Never-married      Other-service  Not-in-family  White    Male
# 6       Never-married                  ?      Unmarried  Black    Male
# 7  Married-civ-spouse     Prof-specialty        Husband  White    Male
# 8       Never-married      Other-service      Unmarried  White  Female
# 9  Married-civ-spouse       Craft-repair        Husband  White    Male
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0              40  United-States  <=50K
# 1             0             0              50  United-States  <=50K
# 2             0             0              40  United-States   >50K
# 3          7688             0              40  United-States   >50K
# 4             0             0              30  United-States  <=50K
# 5             0             0              30  United-States  <=50K
# 6             0             0              40  United-States  <=50K
# 7          3103             0              32  United-States   >50K
# 8             0             0              40  United-States  <=50K
# 9             0             0              10  United-States  <=50K

# %% [markdown]
# ## ***2. Check Last 10 Rows of The Dataset***

# %%
df.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# 48835  Married-civ-spouse    Exec-managerial        Husband
# 48836       Never-married    Protective-serv  Not-in-family
# 48837  Married-civ-spouse       Tech-support           Wife
# 48838  Married-civ-spouse  Machine-op-inspct        Husband
# 48839             Widowed       Adm-clerical      Unmarried
# 48840       Never-married       Adm-clerical      Own-child
# 48841  Married-civ-spouse    Exec-managerial           Wife
#
#                      race  gender  capital-gain  capital-loss  hours-per-week  \
# 48832  Amer-Indian-Eskimo    Male             0             0              40
# 48833               White    Male             0             0              45
# 48834  Asian-Pac-Islander    Male             0             0              11
# 48835               White    Male             0             0              40
# 48836               White    Male             0             0              40
# 48837               White  Female             0             0              38
# 48838               White    Male             0             0              40
# 48839               White  Female             0             0              40
# 48840               White    Male             0             0              20
# 48841               White  Female         15024             0              40
#
#       native-country income
# 48832  United-States  <=50K
# 48833  United-States  <=50K
# 48834         Taiwan  <=50K
# 48835  United-States   >50K
# 48836  United-States  <=50K
# 48837  United-States  <=50K
# 48838  United-States   >50K
# 48839  United-States  <=50K
# 48840  United-States  <=50K
# 48841  United-States   >50K

# %% [markdown]
# ## ***3. Find Shape of Our Dataset (Number of Rows And Number of Columns)***

# %%
df.shape
# Out:
# (48842, 15)

# %% [markdown]
# ## ***4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# ## ***5.Check Null Values And Also Create A Heatmap In The Dataset***

# %%
null_val = df.isnull()
null_val
plt.figure(figsize=(12, 10))
sns.heatmap(null_val, cbar=True, cmap='GnBu')
plt.title('Null Values')
plt.show()

# %% [markdown]
# ## ***6. Fetch Random Sample From the Dataset (50%)***

# %%
rand_df = df.sample(frac=0.5, random_state=42)
rand_df
# Out:
#        age         workclass  fnlwgt   education  educational-num  \
# 7762    56           Private   33115     HS-grad                9
# 23881   25           Private  112847     HS-grad                9
# 30507   43           Private  170525   Bachelors               13
# 28911   32           Private  186788     HS-grad                9
# 19484   39           Private  277886   Bachelors               13
# ...    ...               ...     ...         ...              ...
# 18837   55           Private  320835   Bachelors               13
# 37171   35  Self-emp-not-inc  170174     HS-grad                9
# 18234   21           Private  165475     HS-grad                9
# 27814   24           Private  173679   Assoc-voc               11
# 41169   54           Private  103580  Assoc-acdm               12
#
#            marital-status         occupation   relationship   race  gender  \
# 7762             Divorced      Other-service      Unmarried  White  Female
# 23881  Married-civ-spouse   Transport-moving      Own-child  Other    Male
# 30507            Divorced     Prof-specialty  Not-in-family  White  Female
# 28911  Married-civ-spouse   Transport-moving        Husband  White    Male
# 19484  Married-civ-spouse              Sales           Wife  White  Female
# ...                   ...                ...            ...    ...     ...
# 18837  Married-civ-spouse              Sales        Husband  White    Male
# 37171  Married-civ-spouse       Craft-repair        Husband  White    Male
# 18234  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 27814  Married-civ-spouse      Other-service        Husband  White    Male
# 41169            Divorced    Exec-managerial      Unmarried  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 7762              0             0              40  United-States  <=50K
# 23881             0             0              40  United-States  <=50K
# 30507         14344             0              40  United-States   >50K
# 28911             0             0              40  United-States  <=50K
# 19484             0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 18837             0             0              50  United-States   >50K
# 37171          7298             0              60  United-States   >50K
# 18234             0             0              40  United-States  <=50K
# 27814             0             0              20  United-States  <=50K
# 41169             0             0              55  United-States   >50K
#
# [24421 rows x 15 columns]

# %% [markdown]
# ## ***7. Perform Data Cleaning [Replace'?' with NaN]***

# %%
df.replace('?',np.nan, inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                NaN    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %% [markdown]
# ## ***8. Drop All The Missing Values***

# %%
df.dropna(axis=1, inplace=True)
df
# Out:
#        age  fnlwgt     education  educational-num      marital-status  \
# 0       25  226802          11th                7       Never-married
# 1       38   89814       HS-grad                9  Married-civ-spouse
# 2       28  336951    Assoc-acdm               12  Married-civ-spouse
# 3       44  160323  Some-college               10  Married-civ-spouse
# 4       18  103497  Some-college               10       Never-married
# ...    ...     ...           ...              ...                 ...
# 48837   27  257302    Assoc-acdm               12  Married-civ-spouse
# 48838   40  154374       HS-grad                9  Married-civ-spouse
# 48839   58  151910       HS-grad                9             Widowed
# 48840   22  201490       HS-grad                9       Never-married
# 48841   52  287927       HS-grad                9  Married-civ-spouse
#
#       relationship   race  gender  capital-gain  capital-loss  hours-per-week  \
# 0        Own-child  Black    Male             0             0              40
# 1          Husband  White    Male             0             0              50
# 2          Husband  White    Male             0             0              40
# 3          Husband  Black    Male          7688             0              40
# 4        Own-child  White  Female             0             0              30
# ...            ...    ...     ...           ...           ...             ...
# 48837         Wife  White  Female             0             0              38
# 48838      Husband  White    Male             0             0              40
# 48839    Unmarried  White  Female             0             0              40
# 48840    Own-child  White    Male             0             0              20
# 48841         Wife  White  Female         15024             0              40
#
#       income
# 0      <=50K
# 1      <=50K
# 2       >50K
# 3       >50K
# 4      <=50K
# ...      ...
# 48837  <=50K
# 48838   >50K
# 48839  <=50K
# 48840  <=50K
# 48841   >50K
#
# [48842 rows x 12 columns]

# %% [markdown]
# ## ***9. Check Duplicate Data and Drop Them***

# %%
df[df.duplicated()]
# Out:
#        age  fnlwgt     education  educational-num      marital-status  \
# 864     24  194630     Bachelors               13       Never-married
# 7189    27  151382       HS-grad                9       Never-married
# 9014    20   72055  Some-college               10       Never-married
# 9987    20  162945  Some-college               10       Never-married
# 10155   54  151580     Bachelors               13  Married-civ-spouse
# ...    ...     ...           ...              ...                 ...
# 48641   58  200316       HS-grad                9  Married-civ-spouse
# 48685   35  379959       HS-grad                9            Divorced
# 48736   36  109133     Bachelors               13  Married-civ-spouse
# 48835   53  321865       Masters               14  Married-civ-spouse
# 48836   22  310152  Some-college               10       Never-married
#
#         relationship   race  gender  capital-gain  capital-loss  \
# 864    Not-in-family  White    Male             0             0
# 7189       Own-child  White    Male             0             0
# 9014   Not-in-family  White  Female             0             0
# 9987       Own-child  White    Male             0             0
# 10155        Husband  White    Male             0             0
# ...              ...    ...     ...           ...           ...
# 48641        Husband  White    Male             0             0
# 48685  Not-in-family  White  Female             0             0
# 48736        Husband  White    Male             0             0
# 48835        Husband  White    Male             0             0
# 48836  Not-in-family  White    Male             0             0
#
#        hours-per-week income
# 864                35  <=50K
# 7189               40  <=50K
# 9014               40  <=50K
# 9987               40  <=50K
# 10155              40   >50K
# ...               ...    ...
# 48641              40  <=50K
# 48685              40  <=50K
# 48736              50   >50K
# 48835              40   >50K
# 48836              40  <=50K
#
# [202 rows x 12 columns]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        age  fnlwgt     education  educational-num      marital-status  \
# 0       25  226802          11th                7       Never-married
# 1       38   89814       HS-grad                9  Married-civ-spouse
# 2       28  336951    Assoc-acdm               12  Married-civ-spouse
# 3       44  160323  Some-college               10  Married-civ-spouse
# 4       18  103497  Some-college               10       Never-married
# ...    ...     ...           ...              ...                 ...
# 48837   27  257302    Assoc-acdm               12  Married-civ-spouse
# 48838   40  154374       HS-grad                9  Married-civ-spouse
# 48839   58  151910       HS-grad                9             Widowed
# 48840   22  201490       HS-grad                9       Never-married
# 48841   52  287927       HS-grad                9  Married-civ-spouse
#
#       relationship   race  gender  capital-gain  capital-loss  hours-per-week  \
# 0        Own-child  Black    Male             0             0              40
# 1          Husband  White    Male             0             0              50
# 2          Husband  White    Male             0             0              40
# 3          Husband  Black    Male          7688             0              40
# 4        Own-child  White  Female             0             0              30
# ...            ...    ...     ...           ...           ...             ...
# 48837         Wife  White  Female             0             0              38
# 48838      Husband  White    Male             0             0              40
# 48839    Unmarried  White  Female             0             0              40
# 48840    Own-child  White    Male             0             0              20
# 48841         Wife  White  Female         15024             0              40
#
#       income
# 0      <=50K
# 1      <=50K
# 2       >50K
# 3       >50K
# 4      <=50K
# ...      ...
# 48837  <=50K
# 48838   >50K
# 48839  <=50K
# 48840  <=50K
# 48841   >50K
#
# [48640 rows x 12 columns]

# %% [markdown]
# ## ***10. Get Overall Statistics About The Dataframe***

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48640.000000  4.864000e+04     48640.000000  48640.000000
# mean      38.669346  1.896730e+05        10.078845   1083.240070
# std       13.710649  1.056723e+05         2.571267   7466.886242
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175280e+05         9.000000      0.000000
# 50%       37.000000  1.781090e+05        10.000000      0.000000
# 75%       48.000000  2.376255e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48640.000000    48640.000000
# mean      87.865707       40.431373
# std      403.800998       12.405278
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.describe(include='all')
# Out:
#                  age        fnlwgt education  educational-num  \
# count   48640.000000  4.864000e+04     48640     48640.000000
# unique           NaN           NaN        16              NaN
# top              NaN           NaN   HS-grad              NaN
# freq             NaN           NaN     15704              NaN
# mean       38.669346  1.896730e+05       NaN        10.078845
# std        13.710649  1.056723e+05       NaN         2.571267
# min        17.000000  1.228500e+04       NaN         1.000000
# 25%        28.000000  1.175280e+05       NaN         9.000000
# 50%        37.000000  1.781090e+05       NaN        10.000000
# 75%        48.000000  2.376255e+05       NaN        12.000000
# max        90.000000  1.490400e+06       NaN        16.000000
#
#             marital-status relationship   race gender  capital-gain  \
# count                48640        48640  48640  48640  48640.000000
# unique                   7            6      5      2           NaN
# top     Married-civ-spouse      Husband  White   Male           NaN
# freq                 22289        19628  41570  32500           NaN
# mean                   NaN          NaN    NaN    NaN   1083.240070
# std                    NaN          NaN    NaN    NaN   7466.886242
# min                    NaN          NaN    NaN    NaN      0.000000
# 25%                    NaN          NaN    NaN    NaN      0.000000
# 50%                    NaN          NaN    NaN    NaN      0.000000
# 75%                    NaN          NaN    NaN    NaN      0.000000
# max                    NaN          NaN    NaN    NaN  99999.000000
#
#         capital-loss  hours-per-week income
# count   48640.000000    48640.000000  48640
# unique           NaN             NaN      2
# top              NaN             NaN  <=50K
# freq             NaN             NaN  36985
# mean       87.865707       40.431373    NaN
# std       403.800998       12.405278    NaN
# min         0.000000        1.000000    NaN
# 25%         0.000000       40.000000    NaN
# 50%         0.000000       40.000000    NaN
# 75%         0.000000       45.000000    NaN
# max      4356.000000       99.000000    NaN

# %% [markdown]
# ## ***11. Drop The Columns education-num, capital-gain and capital-loss***

# %%
df.drop(columns=['educational-num','capital-gain','capital-loss'], inplace=True)
df
# Out:
#        age  fnlwgt     education      marital-status relationship   race  \
# 0       25  226802          11th       Never-married    Own-child  Black
# 1       38   89814       HS-grad  Married-civ-spouse      Husband  White
# 2       28  336951    Assoc-acdm  Married-civ-spouse      Husband  White
# 3       44  160323  Some-college  Married-civ-spouse      Husband  Black
# 4       18  103497  Some-college       Never-married    Own-child  White
# ...    ...     ...           ...                 ...          ...    ...
# 48837   27  257302    Assoc-acdm  Married-civ-spouse         Wife  White
# 48838   40  154374       HS-grad  Married-civ-spouse      Husband  White
# 48839   58  151910       HS-grad             Widowed    Unmarried  White
# 48840   22  201490       HS-grad       Never-married    Own-child  White
# 48841   52  287927       HS-grad  Married-civ-spouse         Wife  White
#
#        gender  hours-per-week income
# 0        Male              40  <=50K
# 1        Male              50  <=50K
# 2        Male              40   >50K
# 3        Male              40   >50K
# 4      Female              30  <=50K
# ...       ...             ...    ...
# 48837  Female              38  <=50K
# 48838    Male              40   >50K
# 48839  Female              40  <=50K
# 48840    Male              20  <=50K
# 48841  Female              40   >50K
#
# [48640 rows x 9 columns]

# %% [markdown]
# ## ***12. What Is The Distribution of Age Column Show In Graph?***

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['age'], bins=20, edgecolor='black', alpha=0.7)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# ## ***13. Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method And Also Without Using Between Method***

# %%
df[df['age'].between(17, 48)].shape[0]
# Out:
# 37145

# %%
df[(df['age'] >= 17) & (df['age'] <= 48)].shape[0]
# Out:
# 37145

# %% [markdown]
# ## ***14. What is The Distribution of Workclass Column***

# %% [markdown]
# ## ***15. How Many Person Having Bachelors or Masters Degree***

# %%
df[(df['education'] == 'Bachelors')].shape[0]

# %%
df[(df['education'] == 'Masters')].shape[0]

# %% [markdown]
# ## ***16. Create A Boxplot Of The "Income" Column Against The "Age" Column, Segmented By Gender***

# %%
plt.figure(figsize=(12,10))
sns.boxplot(data=df, x='age', y='income', hue='gender')
plt.title('Boxplot Of The "Income" Column Against The "Age" Column')
plt.xlabel('Age')
plt.ylabel('Income')
plt.show()

# %% [markdown]
# ## ***17. Replace income value [<=50k with 0 and >50k with 1]***

# %%
df['income'] = df['income'].replace({'<=50K':0, '>50K':1})
df
# Out:
#        age  fnlwgt     education      marital-status relationship   race  \
# 0       25  226802          11th       Never-married    Own-child  Black
# 1       38   89814       HS-grad  Married-civ-spouse      Husband  White
# 2       28  336951    Assoc-acdm  Married-civ-spouse      Husband  White
# 3       44  160323  Some-college  Married-civ-spouse      Husband  Black
# 4       18  103497  Some-college       Never-married    Own-child  White
# ...    ...     ...           ...                 ...          ...    ...
# 48837   27  257302    Assoc-acdm  Married-civ-spouse         Wife  White
# 48838   40  154374       HS-grad  Married-civ-spouse      Husband  White
# 48839   58  151910       HS-grad             Widowed    Unmarried  White
# 48840   22  201490       HS-grad       Never-married    Own-child  White
# 48841   52  287927       HS-grad  Married-civ-spouse         Wife  White
#
#        gender  hours-per-week  income
# 0        Male              40       0
# 1        Male              50       0
# 2        Male              40       1
# 3        Male              40       1
# 4      Female              30       0
# ...       ...             ...     ...
# 48837  Female              38       0
# 48838    Male              40       1
# 48839  Female              40       0
# 48840    Male              20       0
# 48841  Female              40       1
#
# [48640 rows x 9 columns]

# %% [markdown]
# ## ***18. Which Workclass getting The Highest Salary***

# %% [markdown]
# ## ***19. Who Has Better Chance To Get Salary >50k Male or Female***

# %% [markdown]
# ## ***20. Convert Workclass Column DataType To Category Datatype***
